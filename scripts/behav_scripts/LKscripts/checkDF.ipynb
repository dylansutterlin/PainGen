# %%
import pandas as pd

dir = '/home/dsutterlin/projects/genPain/'
df = pd.read_csv(dir + 'results/' + 'SCEBLmri_Finaldata_TxT_N36.csv')
print(df.shape)
df.head
# Out:
# (3456, 12)
# <bound method NDFrame.head of       blocktrial  block  temp  condition   RTexp  RTpain        exp  \
# 0            1.0      1  48.0        1.0  2459.0  2459.0  29.039301
# 1            2.0      1  49.0        2.0  2078.0  1373.0  10.078143
# 2            3.0      1  50.0        8.0  3133.0  3039.0  32.486785
# 3            4.0      1  49.0        7.0  3550.0  3765.0  30.475753
# 4            5.0      1  49.0        5.0  1571.0  2876.0   6.056079
# ...          ...    ...   ...        ...     ...     ...        ...
# 3451        12.0      6  49.0        4.0  1202.0   908.0  71.270972
# 3452        13.0      6  49.0        5.0   675.0   693.0  14.100207
# 3453        14.0      6  49.0        5.0   793.0   969.0  14.962078
# 3454        15.0      6  50.0        6.0   588.0   693.0  12.089175
# 3455        16.0      6  48.0        1.0   657.0   448.0  29.326592
#
#            pain       mfpe  cues  social  conflict
# 0     10.652724 -18.386578    -1      -1        -1
# ...

# %%
print(df.isna().sum())
df.describe()
# Out:
# blocktrial      3
# block           0
# temp            3
# condition       3
# RTexp           4
# RTpain          4
# exp           101
# pain           93
# mfpe          181
# cues            0
# social          0
# conflict        0
# dtype: int64
#         blocktrial        block         temp    condition        RTexp  \
# count  3453.000000  3456.000000  3453.000000  3453.000000  3452.000000
# mean      8.494353     3.500000    48.999421     4.498407  2209.274623
# std       4.608394     1.708072     0.707107     2.291682   836.324997
# min       1.000000     1.000000    48.000000     1.000000     0.000000
# 25%       4.000000     2.000000    48.000000     2.000000  1672.000000
# 50%       8.000000     3.500000    49.000000     4.000000  2183.000000
# 75%      12.000000     5.000000    49.000000     6.000000  2748.000000
# max      16.000000     6.000000    50.000000     8.000000  4499.000000
#
#             RTpain          exp         pain         mfpe         cues  \
# ...
